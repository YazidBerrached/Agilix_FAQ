# %%
import datetime
idx =1
list_insertion = []

# %%
import openai
openai.api_key = "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"
import hashlib
from transformers import AutoTokenizer  # Tokenizer for token count

tokenizer = AutoTokenizer.from_pretrained("BAAI/bge-small-en-v1.5")

def get_token_count(text):
    tokens = tokenizer.encode(text, add_special_tokens=True)  # Encode text
    return len(tokens)  # Return number of tokens
def get_content_hash(text):
    return hashlib.sha256(text.encode()).hexdigest()
def get_embedding(text):
    response = openai.embeddings.create(
        model="text-embedding-3-small",
        input=text
    )
    return response.data[0].embedding

# %%
content_text = """
BP6013G2 ALIMENTATION ELECTRIQUE
Besoins en alimentation : 
**service simple** : [3 cable (ligne, neutre, terre)]
230 VAC, 50Hz, 1p, 32A (Réglage du disjoncteur = 40 A max)
**service double N/A ** : [5 cable (ligne 1,ligne 2,ligne 3, neutre, terre)]
400 VAC, 50Hz, 3p, 16A (Réglage du disjoncteur = 20 A max)
IMPORTANT :  le service doit inclure un cable neutre , avec une ligne de tension neutre de 230 VAC
![scéma alimentation](public/img/sp_alimentation_schema.png)

"""
meta_data = {
  "Page": 100,
  "chunk": 1,
  "chunk_size": 100
}
token_count = get_token_count(content_text)

# %%
# del list_insertion[-1]

# %%
list_insertion.append((
        f"poseidon_website_{idx}",  # id
        "poseidon_website",  # name
        json.dumps(meta_data),  # meta_data as JSON string
        None,  # filters
        content_text,  # content
        get_embedding(content_text),  # embedding (stored as JSON string)
        json.dumps({"total_tokens": token_count, "prompt_tokens": token_count}),  # usage (stored as JSON string)
        datetime.datetime.now(),  # created_at
        None,  # updated_at
        get_content_hash(content_text)  # content_hash
    ))
idx+=1
print(f"""la longueur de la liste : {len(list_insertion)} \n\n le contenu :\n {content_text}""")
# Out:
# la longueur de la liste : 77
#
#  le contenu :
#
# BP6013G2 ALIMENTATION ELECTRIQUE
# Besoins en alimentation :
# **service simple** : [3 cable (ligne, neutre, terre)]
# 230 VAC, 50Hz, 1p, 32A (Réglage du disjoncteur = 40 A max)
# **service double N/A ** : [5 cable (ligne 1,ligne 2,ligne 3, neutre, terre)]
# 400 VAC, 50Hz, 3p, 16A (Réglage du disjoncteur = 20 A max)
# IMPORTANT :  le service doit inclure un cable neutre , avec une ligne de tension neutre de 230 VAC
# ![scéma alimentation](public/img/sp_alimentation_schema.png)

# %%
import pandas as pd
import json

# Example list (assuming `list_insertion` is populated)
df = pd.DataFrame(list_insertion, columns=[
    "id", "name", "meta_data", "filters", "content", "embedding",
    "usage", "created_at", "updated_at", "content_hash"
])

# Display DataFrame
df['name'] = 'séminaire_poseidon'
df['created_at'] = datetime.datetime.now()  # created_at
for idx, row in df.iterrows():
    df.loc[idx,'id'] = f"{row['name']}__{idx+1}"
df.head()
# Out:
#                       id                name  \
# 0  séminaire_poseidon__1  séminaire_poseidon
# 1  séminaire_poseidon__2  séminaire_poseidon
# 2  séminaire_poseidon__3  séminaire_poseidon
# 3  séminaire_poseidon__4  séminaire_poseidon
# 4  séminaire_poseidon__5  séminaire_poseidon
#
#                                      meta_data filters  \
# 0   {"Page": 7, "chunk": 1, "chunk_size": 100}    None
# 1   {"Page": 7, "chunk": 1, "chunk_size": 100}    None
# 2   {"Page": 9, "chunk": 1, "chunk_size": 100}    None
# 3   {"Page": 9, "chunk": 1, "chunk_size": 100}    None
# 4  {"Page": 11, "chunk": 1, "chunk_size": 100}    None
#
#                                              content  \
# 0  Sequence de mise en route du M7®\nBoitiers BP ...
# 1  Sequence de mise en route du M7®\nBoitiers BP ...
# 2  Sequence de mise en route du M7®\nBoitiers BP ...
# 3  Sequence de mise en route du M7®\nBoitiers BP ...
# 4  CHOISIR LE BON SETUP (REGLAGE) pour les boitie...
#
#                                            embedding  \
# 0  [-0.012557552196085453, 0.03772970661520958, -...
# 1  [-0.01176406815648079, 0.04295419901609421, -0...
# 2  [-0.0133942486718297, 0.041322145611047745, -0...
# 3  [0.0014577957335859537, 0.05165201798081398, -...
# 4  [-0.001319047762081027, -0.02133682742714882, ...
#
#                                          usage                 created_at  \
# 0  {"total_tokens": 232, "prompt_tokens": 232} 2025-03-23 18:56:26.130205
# 1  {"total_tokens": 206, "prompt_tokens": 206} 2025-03-23 18:56:26.130205
# 2  {"total_tokens": 190, "prompt_tokens": 190} 2025-03-23 18:56:26.130205
# 3  {"total_tokens": 157, "prompt_tokens": 157} 2025-03-23 18:56:26.130205
# 4  {"total_tokens": 124, "prompt_tokens": 124} 2025-03-23 18:56:26.130205
#
#   updated_at                                       content_hash
# 0       None  8468a5b7aa85aadac82f3dbe07bcb610386881b777624f...
# 1       None  3c9fcb5dca2f3e863d3a4401b0312ccef6d9083ab40373...
# 2       None  be19eca106182305074dbb49e1bdedc6cd892aaf1c0342...
# 3       None  ff8bffd9ce0cd789b0b393951abc5a41bf454b9fbb2343...
# 4       None  84d81f802bfb888193981637e465ec770cdded79321999...

# %%
# import psycopg2
# from psycopg2.extras import execute_values

# DATABASE_URL = "postgresql://neondb_owner:npg_CzA3eXY9cwBs@ep-spring-sun-a52z84u0-pooler.us-east-2.aws.neon.tech/neondb?sslmode=require"

# insert_query = """
# INSERT INTO ai.pdf_documents 
# (id, name, meta_data, filters, content, embedding, usage, created_at, updated_at, content_hash)
# VALUES %s
# """

# # Connect to PostgreSQL and insert data
# try:
#     conn = psycopg2.connect(DATABASE_URL)
#     cursor = conn.cursor()
    
#     # Execute batch insert
#     execute_values(cursor, insert_query, list_insertion)
    
#     # Commit and close
#     conn.commit()
#     cursor.close()
#     conn.close()
    
#     print("Data successfully inserted into PostgreSQL.")

# except Exception as e:
#     print(f"Error inserting data: {e}")
# Out:
# Data successfully inserted into PostgreSQL.

# %%
import psycopg2
from psycopg2.extras import execute_values

DATABASE_URL = "postgresql://neondb_owner:npg_CzA3eXY9cwBs@ep-spring-sun-a52z84u0-pooler.us-east-2.aws.neon.tech/neondb?sslmode=require"
rows_list = df.to_records(index=False).tolist()
insert_query = """
INSERT INTO ai.pdf_documents 
(id, name, meta_data, filters, content, embedding, usage, created_at, updated_at, content_hash)
VALUES %s
"""

# Connect to PostgreSQL and insert data
try:
    conn = psycopg2.connect(DATABASE_URL)
    cursor = conn.cursor()
    
    # Execute batch insert
    execute_values(cursor, insert_query, rows_list)
    
    # Commit and close
    conn.commit()
    cursor.close()
    conn.close()
    
    print("Data successfully inserted into PostgreSQL.")

except Exception as e:
    print(f"Error inserting data: {e}")
# Out:
# Data successfully inserted into PostgreSQL.
