# %%
import pandas as pd
df = pd.read_csv('pégasse xl.csv')
df = df.drop(columns=['Unnamed: 0','Unnamed: 1','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11'])
df = df[3:]
df = df.reset_index(drop=True)
df.columns =  df.iloc[0]
df = df[1:]
df = df.reset_index(drop=True)
df.head()
# Out:
# 0   id                       name                              meta_data  \
# 0  NaN  FICHE TECHNIQUE XL Pégase  Page : 4, chunk : 1, chunk_size : 100
# 1  NaN  FICHE TECHNIQUE XL Pégase  Page : 4, chunk : 1, chunk_size : 100
# 2  NaN  FICHE TECHNIQUE XL Pégase  Page : 4, chunk : 1, chunk_size : 100
# 3  NaN  FICHE TECHNIQUE XL Pégase   Page :5, chunk : 1, chunk_size : 100
# 4  NaN  FICHE TECHNIQUE XL Pégase   Page :6, chunk : 1, chunk_size : 100
#
# 0 filters                                            content
# 0     NaN  Dimensions :210 x 170 x 80 cm , Poids net : 28...
# 1     NaN  Balboa Spa touch 2 - Les spas Pégase sont équi...
# 2     NaN  Le Système d’intelligence artificielle M8 mini...
# 3     NaN  Divine Line : La gamme a été conçue dans un es...
# 4     NaN  Poséidon Spa propose une grande variété de jet...

# %%
for idx, row in df.iterrows():
    df.loc[idx,'id'] = f"{row['name']}__{idx+1}"
df.head()
# Out:
# 0                            id                       name  \
# 0  FICHE TECHNIQUE XL Pégase__1  FICHE TECHNIQUE XL Pégase
# 1  FICHE TECHNIQUE XL Pégase__2  FICHE TECHNIQUE XL Pégase
# 2  FICHE TECHNIQUE XL Pégase__3  FICHE TECHNIQUE XL Pégase
# 3  FICHE TECHNIQUE XL Pégase__4  FICHE TECHNIQUE XL Pégase
# 4  FICHE TECHNIQUE XL Pégase__5  FICHE TECHNIQUE XL Pégase
#
# 0                              meta_data filters  \
# 0  Page : 4, chunk : 1, chunk_size : 100     NaN
# 1  Page : 4, chunk : 1, chunk_size : 100     NaN
# 2  Page : 4, chunk : 1, chunk_size : 100     NaN
# 3   Page :5, chunk : 1, chunk_size : 100     NaN
# 4   Page :6, chunk : 1, chunk_size : 100     NaN
#
# 0                                            content
# 0  Dimensions :210 x 170 x 80 cm , Poids net : 28...
# 1  Balboa Spa touch 2 - Les spas Pégase sont équi...
# 2  Le Système d’intelligence artificielle M8 mini...
# 3  Divine Line : La gamme a été conçue dans un es...
# ...

# %%
def parse_metadata(metadata_str):
    try:
        parts = metadata_str.split(", ")
        metadata_dict = {}
        for p in parts:
            kv = p.split(" : ") if " : " in p else p.split(":")  # Gérer les deux formats
            if len(kv) == 2:
                key, value = kv[0].strip(), kv[1].strip()
                metadata_dict[key] = int(value) if value.isdigit() else value
        return json.dumps(metadata_dict, ensure_ascii=False) if metadata_dict else None
    except Exception as e:
        return None  # Ignore les lignes mal formatées

# Appliquer la transformation
df["meta_data"] = df["meta_data"].apply(parse_metadata)
df.head()
# Out:
# 0                            id                       name  \
# 0  FICHE TECHNIQUE XL Pégase__1  FICHE TECHNIQUE XL Pégase
# 1  FICHE TECHNIQUE XL Pégase__2  FICHE TECHNIQUE XL Pégase
# 2  FICHE TECHNIQUE XL Pégase__3  FICHE TECHNIQUE XL Pégase
# 3  FICHE TECHNIQUE XL Pégase__4  FICHE TECHNIQUE XL Pégase
# 4  FICHE TECHNIQUE XL Pégase__5  FICHE TECHNIQUE XL Pégase
#
# 0                                   meta_data filters  \
# 0  {"Page": 4, "chunk": 1, "chunk_size": 100}     NaN
# 1  {"Page": 4, "chunk": 1, "chunk_size": 100}     NaN
# 2  {"Page": 4, "chunk": 1, "chunk_size": 100}     NaN
# 3  {"Page": 5, "chunk": 1, "chunk_size": 100}     NaN
# 4  {"Page": 6, "chunk": 1, "chunk_size": 100}     NaN
#
# 0                                            content
# 0  Dimensions :210 x 170 x 80 cm , Poids net : 28...
# 1  Balboa Spa touch 2 - Les spas Pégase sont équi...
# 2  Le Système d’intelligence artificielle M8 mini...
# 3  Divine Line : La gamme a été conçue dans un es...
# ...

# %%
df['filters']=None
df.head()
# Out:
# 0                            id                       name  \
# 0  FICHE TECHNIQUE XL Pégase__1  FICHE TECHNIQUE XL Pégase
# 1  FICHE TECHNIQUE XL Pégase__2  FICHE TECHNIQUE XL Pégase
# 2  FICHE TECHNIQUE XL Pégase__3  FICHE TECHNIQUE XL Pégase
# 3  FICHE TECHNIQUE XL Pégase__4  FICHE TECHNIQUE XL Pégase
# 4  FICHE TECHNIQUE XL Pégase__5  FICHE TECHNIQUE XL Pégase
#
# 0                                   meta_data filters  \
# 0  {"Page": 4, "chunk": 1, "chunk_size": 100}    None
# 1  {"Page": 4, "chunk": 1, "chunk_size": 100}    None
# 2  {"Page": 4, "chunk": 1, "chunk_size": 100}    None
# 3  {"Page": 5, "chunk": 1, "chunk_size": 100}    None
# 4  {"Page": 6, "chunk": 1, "chunk_size": 100}    None
#
# 0                                            content
# 0  Dimensions :210 x 170 x 80 cm , Poids net : 28...
# 1  Balboa Spa touch 2 - Les spas Pégase sont équi...
# 2  Le Système d’intelligence artificielle M8 mini...
# 3  Divine Line : La gamme a été conçue dans un es...
# ...

# %%
import openai
from tqdm import tqdm
tqdm.pandas()
openai.api_key = "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"

def get_embedding(text):
    response = openai.embeddings.create(
        model="text-embedding-3-small",
        input=text
    )
    return response.data[0].embedding 
df['embedding'] = df['content'].progress_apply(get_embedding)
df.head()
# Out:
# 100%|██████████| 23/23 [00:13<00:00,  1.73it/s]
# 0                            id                       name  \
# 0  FICHE TECHNIQUE XL Pégase__1  FICHE TECHNIQUE XL Pégase
# 1  FICHE TECHNIQUE XL Pégase__2  FICHE TECHNIQUE XL Pégase
# 2  FICHE TECHNIQUE XL Pégase__3  FICHE TECHNIQUE XL Pégase
# 3  FICHE TECHNIQUE XL Pégase__4  FICHE TECHNIQUE XL Pégase
# 4  FICHE TECHNIQUE XL Pégase__5  FICHE TECHNIQUE XL Pégase
#
# 0                                   meta_data filters  \
# 0  {"Page": 4, "chunk": 1, "chunk_size": 100}    None
# 1  {"Page": 4, "chunk": 1, "chunk_size": 100}    None
# 2  {"Page": 4, "chunk": 1, "chunk_size": 100}    None
# 3  {"Page": 5, "chunk": 1, "chunk_size": 100}    None
# 4  {"Page": 6, "chunk": 1, "chunk_size": 100}    None
#
# 0                                            content  \
# 0  Dimensions :210 x 170 x 80 cm , Poids net : 28...
# 1  Balboa Spa touch 2 - Les spas Pégase sont équi...
# 2  Le Système d’intelligence artificielle M8 mini...
# ...

# %%
import hashlib

from transformers import AutoTokenizer  # Tokenizer for token count

tokenizer = AutoTokenizer.from_pretrained("BAAI/bge-small-en-v1.5")
def get_token_count(text):
    tokens = tokenizer.encode(text, add_special_tokens=True) 
    return {"total_tokens": len(tokens), "prompt_tokens": len(tokens)}
def get_content_hash(text):
    return hashlib.sha256(text.encode()).hexdigest()

# %%
df['usage'] = df['content'].progress_apply(get_token_count)
df.head()
# Out:
# ...
# 100%|██████████| 23/23 [00:00<00:00, 2235.61it/s]
# 0                            id                       name  \
# 0  FICHE TECHNIQUE XL Pégase__1  FICHE TECHNIQUE XL Pégase
# 1  FICHE TECHNIQUE XL Pégase__2  FICHE TECHNIQUE XL Pégase
# 2  FICHE TECHNIQUE XL Pégase__3  FICHE TECHNIQUE XL Pégase
# 3  FICHE TECHNIQUE XL Pégase__4  FICHE TECHNIQUE XL Pégase
# 4  FICHE TECHNIQUE XL Pégase__5  FICHE TECHNIQUE XL Pégase
#
# 0                                   meta_data filters  \
# 0  {"Page": 4, "chunk": 1, "chunk_size": 100}    None
# 1  {"Page": 4, "chunk": 1, "chunk_size": 100}    None
# 2  {"Page": 4, "chunk": 1, "chunk_size": 100}    None
# 3  {"Page": 5, "chunk": 1, "chunk_size": 100}    None
# 4  {"Page": 6, "chunk": 1, "chunk_size": 100}    None
#
# 0                                            content  \
# 0  Dimensions :210 x 170 x 80 cm , Poids net : 28...
# 1  Balboa Spa touch 2 - Les spas Pégase sont équi...
# 2  Le Système d’intelligence artificielle M8 mini...
# ...

# %%
import datetime
df['created_at'] = datetime.datetime.now()
df['updated_at'] = None
df.head()
# Out:
# 0                            id                       name  \
# 0  FICHE TECHNIQUE XL Pégase__1  FICHE TECHNIQUE XL Pégase
# 1  FICHE TECHNIQUE XL Pégase__2  FICHE TECHNIQUE XL Pégase
# 2  FICHE TECHNIQUE XL Pégase__3  FICHE TECHNIQUE XL Pégase
# 3  FICHE TECHNIQUE XL Pégase__4  FICHE TECHNIQUE XL Pégase
# 4  FICHE TECHNIQUE XL Pégase__5  FICHE TECHNIQUE XL Pégase
#
# 0                                   meta_data filters  \
# 0  {"Page": 4, "chunk": 1, "chunk_size": 100}    None
# 1  {"Page": 4, "chunk": 1, "chunk_size": 100}    None
# 2  {"Page": 4, "chunk": 1, "chunk_size": 100}    None
# 3  {"Page": 5, "chunk": 1, "chunk_size": 100}    None
# 4  {"Page": 6, "chunk": 1, "chunk_size": 100}    None
#
# 0                                            content  \
# 0  Dimensions :210 x 170 x 80 cm , Poids net : 28...
# 1  Balboa Spa touch 2 - Les spas Pégase sont équi...
# 2  Le Système d’intelligence artificielle M8 mini...
# 3  Divine Line : La gamme a été conçue dans un es...
# ...

# %%
df['content_hash'] = df['content'].progress_apply(get_content_hash)
# Out:
# 100%|██████████| 23/23 [00:00<00:00, 47521.67it/s]

# %%
df.head()
# Out:
# 0                            id                       name  \
# 0  FICHE TECHNIQUE XL Pégase__1  FICHE TECHNIQUE XL Pégase
# 1  FICHE TECHNIQUE XL Pégase__2  FICHE TECHNIQUE XL Pégase
# 2  FICHE TECHNIQUE XL Pégase__3  FICHE TECHNIQUE XL Pégase
# 3  FICHE TECHNIQUE XL Pégase__4  FICHE TECHNIQUE XL Pégase
# 4  FICHE TECHNIQUE XL Pégase__5  FICHE TECHNIQUE XL Pégase
#
# 0                                   meta_data filters  \
# 0  {"Page": 4, "chunk": 1, "chunk_size": 100}    None
# 1  {"Page": 4, "chunk": 1, "chunk_size": 100}    None
# 2  {"Page": 4, "chunk": 1, "chunk_size": 100}    None
# 3  {"Page": 5, "chunk": 1, "chunk_size": 100}    None
# 4  {"Page": 6, "chunk": 1, "chunk_size": 100}    None
#
# 0                                            content  \
# 0  Dimensions :210 x 170 x 80 cm , Poids net : 28...
# 1  Balboa Spa touch 2 - Les spas Pégase sont équi...
# 2  Le Système d’intelligence artificielle M8 mini...
# 3  Divine Line : La gamme a été conçue dans un es...
# ...

# %%
df["meta_data"] = df["meta_data"].apply(json.dumps)  # Convert dictionary to JSON string
#df["embedding"] = df["embedding"].apply(json.dumps)  # Convert list to JSON string
df["usage"] = df["usage"].apply(json.dumps)  # Convert list to JSON string

# %%
import psycopg2
from psycopg2.extras import execute_values

DATABASE_URL = "postgresql://neondb_owner:npg_CzA3eXY9cwBs@ep-spring-sun-a52z84u0-pooler.us-east-2.aws.neon.tech/neondb?sslmode=require"
rows_list = df.to_records(index=False).tolist()
insert_query = """
INSERT INTO ai.pdf_documents 
(id, name, meta_data, filters, content, embedding, usage, created_at, updated_at, content_hash)
VALUES %s
"""

# Connect to PostgreSQL and insert data
try:
    conn = psycopg2.connect(DATABASE_URL)
    cursor = conn.cursor()
    
    # Execute batch insert
    execute_values(cursor, insert_query, rows_list)
    
    # Commit and close
    conn.commit()
    cursor.close()
    conn.close()
    
    print("Data successfully inserted into PostgreSQL.")

except Exception as e:
    print(f"Error inserting data: {e}")
# Out:
# Data successfully inserted into PostgreSQL.
